# %% [markdown]
# <a href="https://colab.research.google.com/github/gaddamarchana/1221/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
X = np.array([[4], [6], [8], [9], [13]])  # Independent variable
Y = np.array([1, 2, 2.5, 4, 5])  # Dependent variable

# %%
model = LinearRegression()
model.fit(X, Y)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X)

# %%
plt.scatter(X, Y, color='blue')  # Actual data points
plt.plot(X, Y_pred, color='red')  # Regression line
plt.title("Linear Regression")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
print("Intercept (β0):", model.intercept_)
print("Coefficient (β1):", model.coef_)
# Out:
# Intercept (β0): -0.7521739130434781
# Coefficient (β1): [0.45652174]

# %%
X = np.random.rand(100, 1) * 50  # 100 random numbers between 0 and 100
Y = 2 * X + np.random.randn(100, 1) * 10  # Linear relation with some noise

# %%
plt.scatter(X, Y, color='blue')
plt.title("Generated Dataset of 100 Numbers")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
model = LinearRegression()
model.fit(X, Y)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X)

# %%
plt.scatter(X, Y, color='blue')  # Actual data points
plt.plot(X, Y_pred, color='red')  # Regression line
plt.title("Linear Regression")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
print("Intercept (β0):", model.intercept_)
print("Coefficient (β1):", model.coef_)
# Out:
# Intercept (β0): [-0.54173586]
# Coefficient (β1): [[2.01995639]]

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/kgsb24/rishi-college/refs/heads/main/datasets/diabetes.csv')

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
import sklearn.linear_model

# %%
from sklearn.linear_model import LinearRegression

# %%
import sklearn

# %%
help(LinearRegression)
# Out:
# Help on class LinearRegression in module sklearn.linear_model._base:
#
# class LinearRegression(sklearn.base.MultiOutputMixin, sklearn.base.RegressorMixin, LinearModel)
#  |  LinearRegression(*, fit_intercept=True, copy_X=True, n_jobs=None, positive=False)
#  |
#  |  Ordinary least squares Linear Regression.
#  |
#  |  LinearRegression fits a linear model with coefficients w = (w1, ..., wp)
#  |  to minimize the residual sum of squares between the observed targets in
#  |  the dataset, and the targets predicted by the linear approximation.
#  |
#  |  Parameters
#  |  ----------
#  |  fit_intercept : bool, default=True
#  |      Whether to calculate the intercept for this model. If set
#  |      to False, no intercept will be used in calculations
#  |      (i.e. data is expected to be centered).
#  |
#  |  copy_X : bool, default=True
#  |      If True, X will be copied; else, it may be overwritten.
#  |
#  |  n_jobs : int, default=None
# ...
